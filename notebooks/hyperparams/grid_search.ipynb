# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt

from os import listdir
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier, IsolationForest
from sklearn.metrics import f1_score, accuracy_score, matthews_corrcoef, precision_score, roc_auc_score, recall_score, average_precision_score, make_scorer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier, LocalOutlierFactor
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, MinMaxScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from tqdm import tqdm

# %%
def score_model(model, X_test, y_test, map = None):
    model_preds = model.predict(X_test)
    scores = {}
    if map:
        model_preds = [map[i] for i in model_preds]
    evaluation_funcs = {'accuracy':accuracy_score, 'precision':precision_score, 'recall':recall_score, 'f1':f1_score, 'MCC':matthews_corrcoef}
    for name, score in evaluation_funcs.items():
        scores[name] = score(y_pred = model_preds, y_true = y_test)
    scores['ROC-AUC'] = roc_auc_score(y_score = model_preds, y_true = y_test)
    scores['AUPR'] = average_precision_score(y_score = model_preds, y_true = y_test)
    return scores

# %%
transaction_df = pd.read_csv('original_data.csv')
#Split data to x, y, train, test
y = transaction_df['fraud']
X = transaction_df.drop(columns=['fraud'])
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
#Fit transformer to data
transformer = ColumnTransformer([('One Hot Encoder', OneHotEncoder(drop='first'), ['category', 'gender']),
                                 ('Age Pipe', Pipeline([('ord', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)), ('scale', MinMaxScaler())]), ['age']),
                                 ('MinMaxScaler', MinMaxScaler(), ['amount', 'step']),
                                 ('drop', 'drop', ['zipcodeOri', 'zipMerchant', 'customer', 'merchant'])], remainder = MinMaxScaler(), sparse_threshold=0)
transformer.fit(X_train)
X_train_transformed = transformer.transform(X_train)
X_test_transformed = transformer.transform(X_test)

# %%
roc_auc_scorer = make_scorer(roc_auc_score)

# %%
param_grid = {'criterion': ['gini', 'entropy']}

decision_tree_grid = GridSearchCV(DecisionTreeClassifier(random_state=42), 
                                    param_grid,
                                    scoring = roc_auc_scorer,
                                    verbose=1,
                                    n_jobs=-1)
decision_tree_grid.fit(X_train_transformed, y_train)
dec_tree_grid_scores = score_model(decision_tree_grid, X_test_transformed, y_test)
dec_tree_grid_scores
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# {'accuracy': 0.9913090857723277,
#  'precision': 0.6225910064239829,
#  'recall': 0.6645714285714286,
#  'f1': 0.6428966279712548,
#  'MCC': 0.6388506653966829,
#  'ROC-AUC': 0.8298863023968837,
#  'AUPR': 0.41770477555463403}

# %%
# Random Forest
param_grid = {'criterion': ['gini', 'entropy'],
              'class_weight':['balanced', 'balanced_subsample', None],}
random_forest_grid = GridSearchCV(RandomForestClassifier(random_state=42), 
                                    param_grid,
                                    scoring = roc_auc_scorer,
                                    verbose=1,
                                    n_jobs=-1)
random_forest_grid.fit(X_train_transformed, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# /home/stu15/s10/mjh9122/miniconda3/envs/fraud/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/stu15/s10/mjh9122/Research/fraud_detection/notebooks/hyperparams/grid_search.ipynb Cell 7 line 9
#       <a href='vscode-notebook-cell://ssh-remote%2Bberyllium/home/stu15/s10/mjh9122/Research/fraud_detection/notebooks/hyperparams/grid_search.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> param_grid = {'criterion': ['gini', 'entropy'],
#       <a href='vscode-notebook-cell://ssh-remote%2Bberyllium/home/stu15/s10/mjh9122/Research/fraud_detection/notebooks/hyperparams/grid_search.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>               'class_weight':['balanced', 'balanced_subsample', None],}
#       <a href='vscode-notebook-cell://ssh-remote%2Bberyllium/home/stu15/s10/mjh9122/Research/fraud_detection/notebooks/hyperparams/grid_search.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> random_forest_grid = GridSearchCV(RandomForestClassifier(random_state=42, n_jobs = -1),
#       <a href='vscode-notebook-cell://ssh-remote%2Bberyllium/home/stu15/s10/mjh9122/Research/fraud_detection/notebooks/hyperparams/grid_search.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>                                     param_grid,
#       <a href='vscode-notebook-cell://ssh-remote%2Bberyllium/home/stu15/s10/mjh9122/Research/fraud_detection/notebooks/hyperparams/grid_search.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>                                     scoring = roc_auc_scorer,
#       <a href='vscode-notebook-cell://ssh-remote%2Bberyllium/home/stu15/s10/mjh9122/Research/fraud_detection/notebooks/hyperparams/grid_search.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>                                     verbose=1,
#       <a href='vscode-notebook-cell://ssh-remote%2Bberyllium/home/stu15/s10/mjh9122/Research/fraud_detection/notebooks/hyperparams/grid_search.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>                                     n_jobs=-1)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bberyllium/home/stu15/s10/mjh9122/Research/fraud_detection/notebooks/hyperparams/grid_search.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> random_forest_grid.fit(X_train_transformed, y_train)
#
# File ~/miniconda3/envs/fraud/lib/python3.11/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/fraud/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/miniconda3/envs/fraud/lib/python3.11/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~/miniconda3/envs/fraud/lib/python3.11/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/fraud/lib/python3.11/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/miniconda3/envs/fraud/lib/python3.11/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/miniconda3/envs/fraud/lib/python3.11/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/miniconda3/envs/fraud/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/miniconda3/envs/fraud/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
random_forest_scores_grid = score_model(random_forest_grid, X_test_transformed, y_test)
random_forest_scores_grid
# Out:
# {'accuracy': 0.9947464365233653,
#  'precision': 0.862378459237098,
#  'recall': 0.6588571428571428,
#  'f1': 0.747003563330094,
#  'MCC': 0.7512917590930227,
#  'ROC-AUC': 0.8288023419426922,
#  'AUPR': 0.5722000558522087}

# %%
# KNN
param_grid = {'n_neighbors':range(5, 15, 2),
                            'weights':['uniform', 'distance'],
                            'p':[1, 2]}
KNN_grid = GridSearchCV(KNeighborsClassifier(n_jobs = -1), 
                        param_grid,
                        scoring = roc_auc_scorer,
                        verbose=2,
                        n_jobs=-1)
KNN_grid.fit(X_train_transformed, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END ................n_neighbors=5, p=2, weights=uniform; total time= 3.5min
# [CV] END ................n_neighbors=5, p=2, weights=uniform; total time= 3.7min
# [CV] END ................n_neighbors=5, p=2, weights=uniform; total time= 3.4min
# [CV] END ................n_neighbors=5, p=2, weights=uniform; total time= 3.6min
# [CV] END ................n_neighbors=5, p=2, weights=uniform; total time= 3.7min
# [CV] END ...............n_neighbors=5, p=2, weights=distance; total time= 3.5min
# [CV] END ...............n_neighbors=5, p=2, weights=distance; total time= 3.4min
# [CV] END ...............n_neighbors=5, p=2, weights=distance; total time= 3.5min
# [CV] END ...............n_neighbors=5, p=2, weights=distance; total time= 3.6min
# [CV] END ...............n_neighbors=5, p=2, weights=distance; total time= 3.4min
# [CV] END ................n_neighbors=5, p=1, weights=uniform; total time=18.1min
# [CV] END ...............n_neighbors=5, p=1, weights=distance; total time=18.3min
# [CV] END ...............n_neighbors=5, p=1, weights=distance; total time=18.4min
# [CV] END ................n_neighbors=5, p=1, weights=uniform; total time=18.4min
# [CV] END ................n_neighbors=5, p=1, weights=uniform; total time=18.5min
# [CV] END ...............n_neighbors=5, p=1, weights=distance; total time=18.5min
# [CV] END ................n_neighbors=5, p=1, weights=uniform; total time=18.5min
# [CV] END ...............n_neighbors=5, p=1, weights=distance; total time=18.6min
# [CV] END ...............n_neighbors=5, p=1, weights=distance; total time=18.7min
# [CV] END ................n_neighbors=5, p=1, weights=uniform; total time=19.0min
# [CV] END ................n_neighbors=7, p=2, weights=uniform; total time= 3.6min
# [CV] END ................n_neighbors=7, p=2, weights=uniform; total time= 3.6min
# [CV] END ................n_neighbors=7, p=2, weights=uniform; total time= 3.4min
# [CV] END ................n_neighbors=7, p=2, weights=uniform; total time= 3.7min
# [CV] END ................n_neighbors=7, p=2, weights=uniform; total time= 3.5min
# [CV] END ...............n_neighbors=7, p=2, weights=distance; total time= 3.6min
# [CV] END ...............n_neighbors=7, p=2, weights=distance; total time= 3.6min
# [CV] END ...............n_neighbors=7, p=2, weights=distance; total time= 3.7min
# [CV] END ................n_neighbors=7, p=1, weights=uniform; total time=18.2min
# [CV] END ................n_neighbors=7, p=1, weights=uniform; total time=18.7min
# [CV] END ...............n_neighbors=7, p=1, weights=distance; total time=18.0min
# [CV] END ................n_neighbors=7, p=1, weights=uniform; total time=18.3min
# [CV] END ...............n_neighbors=7, p=2, weights=distance; total time= 3.6min
# [CV] END ...............n_neighbors=7, p=1, weights=distance; total time=18.2min
# [CV] END ................n_neighbors=7, p=1, weights=uniform; total time=18.7min
# [CV] END ...............n_neighbors=7, p=2, weights=distance; total time= 3.5min
# [CV] END ...............n_neighbors=7, p=1, weights=distance; total time=18.5min
# [CV] END ...............n_neighbors=7, p=1, weights=distance; total time=18.5min
# [CV] END ................n_neighbors=7, p=1, weights=uniform; total time=18.8min
# [CV] END ...............n_neighbors=7, p=1, weights=distance; total time=18.7min
# [CV] END ................n_neighbors=9, p=2, weights=uniform; total time= 3.7min
# [CV] END ................n_neighbors=9, p=2, weights=uniform; total time= 3.7min
# [CV] END ................n_neighbors=9, p=2, weights=uniform; total time= 3.6min
# [CV] END ................n_neighbors=9, p=2, weights=uniform; total time= 3.6min
# [CV] END ................n_neighbors=9, p=2, weights=uniform; total time= 3.7min
# [CV] END ...............n_neighbors=9, p=2, weights=distance; total time= 3.6min
# [CV] END ...............n_neighbors=9, p=2, weights=distance; total time= 3.4min
# [CV] END ...............n_neighbors=9, p=2, weights=distance; total time= 3.2min
# [CV] END ................n_neighbors=9, p=1, weights=uniform; total time=18.4min
# [CV] END ................n_neighbors=9, p=1, weights=uniform; total time=18.0min
# [CV] END ...............n_neighbors=9, p=1, weights=distance; total time=17.8min
# [CV] END ................n_neighbors=9, p=1, weights=uniform; total time=18.2min
# [CV] END ...............n_neighbors=9, p=1, weights=distance; total time=17.9min
# [CV] END ...............n_neighbors=9, p=2, weights=distance; total time= 3.2min
# [CV] END ...............n_neighbors=9, p=2, weights=distance; total time= 3.2min
# [CV] END ...............n_neighbors=9, p=1, weights=distance; total time=17.9min
# [CV] END ...............n_neighbors=9, p=1, weights=distance; total time=17.8min
# [CV] END ................n_neighbors=9, p=1, weights=uniform; total time=18.2min
# [CV] END ...............n_neighbors=9, p=1, weights=distance; total time=17.9min
# [CV] END ................n_neighbors=9, p=1, weights=uniform; total time=18.3min
# [CV] END ...............n_neighbors=11, p=2, weights=uniform; total time= 3.3min
# [CV] END ...............n_neighbors=11, p=2, weights=uniform; total time= 3.3min
# [CV] END ...............n_neighbors=11, p=2, weights=uniform; total time= 3.3min
# [CV] END ...............n_neighbors=11, p=2, weights=uniform; total time= 3.3min
# [CV] END ..............n_neighbors=11, p=2, weights=distance; total time= 3.2min
# [CV] END ...............n_neighbors=11, p=2, weights=uniform; total time= 3.3min
# [CV] END ..............n_neighbors=11, p=2, weights=distance; total time= 3.2min
# [CV] END ..............n_neighbors=11, p=2, weights=distance; total time= 3.2min
# [CV] END ..............n_neighbors=11, p=2, weights=distance; total time= 3.2min
# [CV] END ..............n_neighbors=11, p=2, weights=distance; total time= 3.2min
# [CV] END ...............n_neighbors=11, p=1, weights=uniform; total time=17.0min
# [CV] END ...............n_neighbors=11, p=1, weights=uniform; total time=17.0min
# [CV] END ..............n_neighbors=11, p=1, weights=distance; total time=16.8min
# [CV] END ...............n_neighbors=11, p=1, weights=uniform; total time=17.0min
# [CV] END ...............n_neighbors=11, p=1, weights=uniform; total time=17.0min
# [CV] END ..............n_neighbors=11, p=1, weights=distance; total time=16.9min
# [CV] END ..............n_neighbors=11, p=1, weights=distance; total time=16.9min
# [CV] END ...............n_neighbors=11, p=1, weights=uniform; total time=17.0min
# [CV] END ..............n_neighbors=11, p=1, weights=distance; total time=16.9min
# [CV] END ..............n_neighbors=11, p=1, weights=distance; total time=16.9min
# [CV] END ...............n_neighbors=13, p=2, weights=uniform; total time= 3.3min
# [CV] END ...............n_neighbors=13, p=2, weights=uniform; total time= 3.3min
# [CV] END ...............n_neighbors=13, p=2, weights=uniform; total time= 3.3min
# [CV] END ...............n_neighbors=13, p=2, weights=uniform; total time= 3.3min
# [CV] END ...............n_neighbors=13, p=2, weights=uniform; total time= 3.3min
# [CV] END ..............n_neighbors=13, p=2, weights=distance; total time= 3.2min
# [CV] END ..............n_neighbors=13, p=2, weights=distance; total time= 3.2min
# [CV] END ..............n_neighbors=13, p=2, weights=distance; total time= 3.2min
# [CV] END ..............n_neighbors=13, p=2, weights=distance; total time= 3.2min
# [CV] END ..............n_neighbors=13, p=2, weights=distance; total time= 3.2min
# [CV] END ...............n_neighbors=13, p=1, weights=uniform; total time=16.8min
# [CV] END ...............n_neighbors=13, p=1, weights=uniform; total time=17.0min
# [CV] END ...............n_neighbors=13, p=1, weights=uniform; total time=16.9min
# [CV] END ..............n_neighbors=13, p=1, weights=distance; total time=16.7min
# [CV] END ...............n_neighbors=13, p=1, weights=uniform; total time=16.9min
# [CV] END ...............n_neighbors=13, p=1, weights=uniform; total time=16.8min
# [CV] END ..............n_neighbors=13, p=1, weights=distance; total time=16.8min
# [CV] END ..............n_neighbors=13, p=1, weights=distance; total time=16.7min
# [CV] END ..............n_neighbors=13, p=1, weights=distance; total time=16.8min
# [CV] END ..............n_neighbors=13, p=1, weights=distance; total time=16.7min
# GridSearchCV(estimator=KNeighborsClassifier(n_jobs=-1), n_jobs=-1,
#              param_grid={'n_neighbors': range(5, 15, 2), 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              refit='roc-auc',
#              scoring={'accuracy': make_scorer(accuracy_score),
#                       'aupr': make_scorer(average_precision_score),
#                       'f1': make_scorer(f1_score),
#                       'mcc': make_scorer(matthews_corrcoef),
#                       'precision': make_scorer(precision_score),
#                       'recall': make_scorer(recall_score),
#                       'roc-auc': make_scorer(roc_auc_score)},
#              verbose=2)

# %%
KNN_grid_scores = score_model(KNN_grid, X_test_transformed, y_test)
KNN_grid_scores
# Out:
# {'accuracy': 0.9922171921351263,
#  'precision': 0.743631881676253,
#  'recall': 0.5171428571428571,
#  'f1': 0.6100438153016514,
#  'MCC': 0.6164682229734424,
#  'ROC-AUC': 0.757509561182329,
#  'AUPR': 0.39024798911231584}

# %%
#Multilayer perceptron
param_grid = {'hidden_layer_sizes': [(10, 10, 10), (15, 15, 15), (20, 20, 20),],
            'activation': ['tanh', 'relu'],
            'solver':['sgd', 'adam'],
            'alpha': [.001, .01, .1],
            'learning_rate':['constant', 'adaptive']}
MLP_grid = GridSearchCV(MLPClassifier(random_state=42), 
                        param_grid,
                        scoring = roc_auc_scorer,
                        verbose=2,
                        n_jobs=-1)
MLP_grid.fit(X_train_transformed, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  40.3s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  40.7s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  40.8s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  40.9s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  42.3s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  39.9s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  41.9s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  39.7s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  39.9s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.5min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.5min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.5min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.6min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.6min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  40.2s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  48.4s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  46.4s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 4.1min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 4.1min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  46.2s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  54.9s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.6min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 4.1min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 4.2min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  46.7s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.4min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.5min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 4.3min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.7min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  48.0s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  47.1s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  46.2s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  46.0s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  55.2s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time=  51.0s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.2min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time=  51.2s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time=  53.8s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.4min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.3min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.2min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.5min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.6min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.1min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.6min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.3min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.2min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.4min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.6min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time=  52.4s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time=  51.0s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time=  53.9s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.2min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.2min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  39.9s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  46.5s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  51.2s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.4min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.4min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  51.9s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.5min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  40.5s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.5min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.5min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  39.9s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  46.5s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 5.6min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  51.0s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  51.9s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 5.5min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  40.3s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 5.5min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 5.8min
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 6.0min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  48.6s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time= 1.1min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 4.1min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 4.1min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 4.4min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  59.9s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.4min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 4.2min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.2min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  59.7s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.5min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 4.4min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  57.3s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  48.4s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  55.1s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time= 1.0min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time= 1.0min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time= 1.0min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.3min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.3min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time=  57.9s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.4min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.3min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.3min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.2min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.3min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.5min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.6min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.2min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.1min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.5min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.4min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.2min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time=  54.7s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.3min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.2min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.3min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.2min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  38.2s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  36.5s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  40.1s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  40.4s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.2min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  39.8s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.4min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  38.4s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  36.1s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  40.3s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  40.5s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 5.7min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 5.7min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 5.6min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  40.3s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 6.1min
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 5.8min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  47.7s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.9min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  49.6s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.9min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.9min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  45.6s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.9min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 4.1min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  57.6s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  58.9s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.6min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 3.0min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.7min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.9min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.6min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  48.6s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  51.4s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  46.3s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  57.8s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time= 1.0min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.0min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.1min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.0min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time=  54.6s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.6min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.8min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.6min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.7min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.6min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.1min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.9min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 4.8min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.8min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.8min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 3.9min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.1min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time=  54.7s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.1min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.1min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.2min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  41.3s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  37.1s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  58.6s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  51.8s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  51.0s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  39.4s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  42.2s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  57.0s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  56.5s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 6.4min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 6.4min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 6.5min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  50.0s
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 6.1min
# [CV] END activation=tanh, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 6.2min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.2min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.7min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.6min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time= 1.0min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time= 1.0min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  53.9s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  59.9s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time= 1.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.0min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  55.0s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  56.5s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  59.2s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  51.9s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time= 1.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time=  55.5s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.5min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.3min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.3min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.2min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.0min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.5min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time=  52.7s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time=  57.6s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.3min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.5min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.3min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time= 1.1min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.2min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time= 1.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 3.7min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 3.8min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 3.7min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.2min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 2.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 3.7min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 3.7min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  50.0s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time= 1.1min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time= 1.1min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time= 1.1min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  49.3s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time= 1.1min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time= 1.2min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time= 1.3min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time= 1.0min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.0min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time= 1.6min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.4min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.0min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 1.9min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time= 1.0min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.4min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.5min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.7min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 3.7min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time= 1.3min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time= 1.5min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  59.9s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time= 1.0min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time= 1.5min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time= 1.3min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time= 1.5min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.3min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.2min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.5min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.4min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.3min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.2min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.7min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.7min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.7min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.2min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.4min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.3min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.6min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.6min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.3min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.6min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.4min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.6min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 1.3min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  41.1s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 1.3min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  38.2s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 1.4min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  41.4s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 1.3min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  38.4s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=sgd; total time= 1.5min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=constant, solver=adam; total time=  40.4s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 3.6min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 3.7min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 3.6min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 3.7min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 4.0min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  40.1s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  37.9s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  37.0s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  38.2s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=adam; total time=  40.0s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  43.6s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  44.6s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 2.6min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.0min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 2.7min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  44.5s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 2.7min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  45.6s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 1.9min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 2.6min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 10, 10), learning_rate=adaptive, solver=sgd; total time= 2.7min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.2min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=adam; total time=  51.5s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=constant, solver=sgd; total time= 2.3min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  43.0s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  45.1s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  43.3s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  46.1s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=adam; total time=  53.4s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.0min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.0min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.3min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.4min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.1min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.6min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.6min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time=  56.5s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.5min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.4min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.5min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.7min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(15, 15, 15), learning_rate=adaptive, solver=sgd; total time= 3.6min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=sgd; total time= 2.8min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time=  55.5s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time=  59.9s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time=  55.0s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time=  58.2s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=constant, solver=adam; total time= 1.4min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=adam; total time= 1.2min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 2.3min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 2.6min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 2.6min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 2.7min
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20, 20, 20), learning_rate=adaptive, solver=sgd; total time= 2.7min
# GridSearchCV(estimator=MLPClassifier(random_state=42), n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.001, 0.01, 0.1],
#                          'hidden_layer_sizes': [(10, 10, 10), (15, 15, 15),
#                                                 (20, 20, 20)],
#                          'learning_rate': ['constant', 'adaptive'],
#                          'solver': ['sgd', 'adam']},
#              refit='roc-auc',
#              scoring={'accuracy': make_scorer(accuracy_score),
#                       'aupr': make_scorer(average_precision_score),
#                       'f1': make_scorer(f1_score),
#                       'mcc': make_scorer(matthews_corrcoef),
#                       'precision': make_scorer(precision_score),
#                       'recall': make_scorer(recall_score),
#                       'roc-auc': make_scorer(roc_auc_score)},
#              verbose=2)

# %%
MLP_grid_scores = score_model(MLP_grid, X_test_transformed, y_test)
MLP_grid_scores
# Out:
# {'accuracy': 0.9950222317891041,
#  'precision': 0.9279661016949152,
#  'recall': 0.6257142857142857,
#  'f1': 0.7474402730375427,
#  'MCC': 0.7598212674065462,
#  'ROC-AUC': 0.8125678520620356,
#  'AUPR': 0.5850476440271268}

# %%
param_grid = {'C': [2**i for i in range(-5, 15, 2)], 
              'gamma': [2**i for i in range(-15, 3, 2)],
              'class_weight':['balanced', {0:1, 1:1}]}
#Support Vector machine
SVM_grid = GridSearchCV(SVC(kernel='rbf', random_state=42),
                    param_grid,   
                    scoring = roc_auc_scorer,
                    verbose=2,
                    n_jobs=-1)
SVM_grid.fit(X_train_transformed, y_train)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [CV] END C=0.03125, class_weight=balanced, gamma=0.00048828125; total time=553.0min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.00048828125; total time=554.4min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.0001220703125; total time=640.4min
# [CV] END C=0.03125, class_weight=balanced, gamma=3.0517578125e-05; total time=640.8min
# [CV] END C=0.03125, class_weight=balanced, gamma=3.0517578125e-05; total time=643.2min
# [CV] END C=0.03125, class_weight=balanced, gamma=3.0517578125e-05; total time=648.6min
# [CV] END C=0.03125, class_weight=balanced, gamma=3.0517578125e-05; total time=652.2min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.0001220703125; total time=653.0min
# [CV] END C=0.03125, class_weight=balanced, gamma=3.0517578125e-05; total time=656.1min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.0001220703125; total time=658.1min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.0001220703125; total time=664.3min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.0001220703125; total time=667.0min
# [CV] END .C=0.03125, class_weight=balanced, gamma=0.0078125; total time=126.2min
# [CV] END .C=0.03125, class_weight=balanced, gamma=0.0078125; total time=123.0min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.001953125; total time=193.0min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.001953125; total time=193.9min
# [CV] END .C=0.03125, class_weight=balanced, gamma=0.0078125; total time=215.2min
# [CV] END .C=0.03125, class_weight=balanced, gamma=0.0078125; total time=225.1min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.001953125; total time=250.8min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.001953125; total time=269.2min
# [CV] END ....C=0.03125, class_weight=balanced, gamma=0.03125; total time=63.7min
# [CV] END ......C=0.03125, class_weight=balanced, gamma=0.125; total time=55.5min
# [CV] END ....C=0.03125, class_weight=balanced, gamma=0.03125; total time=65.8min
# [CV] END ......C=0.03125, class_weight=balanced, gamma=0.125; total time=50.9min
# [CV] END ...C=0.03125, class_weight=balanced, gamma=0.03125; total time=183.6min
# [CV] END ......C=0.03125, class_weight=balanced, gamma=0.125; total time=53.8min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.001953125; total time=346.4min
# [CV] END ......C=0.03125, class_weight=balanced, gamma=0.125; total time=53.5min
# [CV] END ........C=0.03125, class_weight=balanced, gamma=0.5; total time=50.7min
# [CV] END ......C=0.03125, class_weight=balanced, gamma=0.125; total time=63.2min
# [CV] END ...C=0.03125, class_weight=balanced, gamma=0.03125; total time=172.1min
# [CV] END ...C=0.03125, class_weight=balanced, gamma=0.03125; total time=186.3min
# [CV] END ........C=0.03125, class_weight=balanced, gamma=0.5; total time=49.7min
# [CV] END .C=0.03125, class_weight=balanced, gamma=0.0078125; total time=255.6min
# [CV] END ........C=0.03125, class_weight=balanced, gamma=0.5; total time=50.4min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=3.0517578125e-05; total time=12.3min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=3.0517578125e-05; total time=12.0min
# [CV] END ........C=0.03125, class_weight=balanced, gamma=0.5; total time=55.7min
# [CV] END ........C=0.03125, class_weight=balanced, gamma=0.5; total time=52.7min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=3.0517578125e-05; total time=12.4min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=3.0517578125e-05; total time= 9.4min
# [CV] END ..........C=0.03125, class_weight=balanced, gamma=2; total time=52.3min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=3.0517578125e-05; total time=12.9min
# [CV] END ..........C=0.03125, class_weight=balanced, gamma=2; total time=52.1min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.0001220703125; total time=11.0min
# [CV] END ..........C=0.03125, class_weight=balanced, gamma=2; total time=54.3min
# [CV] END ..........C=0.03125, class_weight=balanced, gamma=2; total time=51.0min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.0001220703125; total time=11.3min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.0001220703125; total time=11.5min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.0001220703125; total time=10.7min
# [CV] END ..........C=0.03125, class_weight=balanced, gamma=2; total time=52.9min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.0001220703125; total time=11.1min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.00048828125; total time=11.4min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.00048828125; total time=443.1min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.00048828125; total time=11.9min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.00048828125; total time=12.2min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.00048828125; total time=12.8min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.00048828125; total time=12.6min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.001953125; total time=12.5min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.001953125; total time=12.7min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.001953125; total time=11.5min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.001953125; total time=11.5min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.001953125; total time=11.9min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.0078125; total time=11.6min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.0078125; total time=12.3min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.0078125; total time=12.5min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.0078125; total time=12.2min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.0078125; total time=12.9min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.03125; total time=13.0min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.03125; total time=13.4min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.03125; total time=13.5min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.00048828125; total time=549.2min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.03125; total time=13.4min
# [CV] END C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.03125; total time=12.9min
# [CV] END ..C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.125; total time=13.8min
# [CV] END ..C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.125; total time=15.4min
# [CV] END ..C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.125; total time=15.6min
# [CV] END ....C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.5; total time=13.5min
# [CV] END ..C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.125; total time=13.8min
# [CV] END C=0.03125, class_weight=balanced, gamma=0.00048828125; total time=560.3min
# [CV] END ..C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.125; total time=14.9min
# [CV] END ....C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.5; total time=13.4min
# [CV] END ....C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.5; total time=13.1min
# [CV] END ....C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.5; total time=12.5min
# [CV] END ....C=0.03125, class_weight={0: 1, 1: 1}, gamma=0.5; total time=12.7min
# [CV] END ......C=0.03125, class_weight={0: 1, 1: 1}, gamma=2; total time=13.8min
# [CV] END ......C=0.03125, class_weight={0: 1, 1: 1}, gamma=2; total time=14.0min
# [CV] END ......C=0.03125, class_weight={0: 1, 1: 1}, gamma=2; total time=14.6min
# [CV] END ......C=0.03125, class_weight={0: 1, 1: 1}, gamma=2; total time=13.6min
# [CV] END ......C=0.03125, class_weight={0: 1, 1: 1}, gamma=2; total time=17.4min
# [CV] END C=0.125, class_weight=balanced, gamma=0.00048828125; total time=207.2min
# [CV] END C=0.125, class_weight=balanced, gamma=0.00048828125; total time=212.2min

# %%
SVM_grid_scores = score_model(SVM_grid, X_test_transformed, y_test)
SVM_grid_scores
# Out:
# {'accuracy': 0.93530246668595,
#  'precision': 0.15167345493182222,
#  'recall': 0.9788571428571429,
#  'f1': 0.26264949402023924,
#  'MCC': 0.3719260199574464,
#  'ROC-AUC': 0.9568203936883068,
#  'AUPR': 0.14871553315237993}

# %%
y_train_transformed = y_train.map({0:-1, 1:1})
y_test_transformed = y_test.map({0:-1, 1:1})

param_grid = {'n_estimators': range(100, 900, 100), 
              'max_samples': range(100, 500, 100), 
              'max_features': [.25, .5, .75, 1.0]}

ISO_grid = GridSearchCV(IsolationForest(random_state=42, n_jobs=-1),
                        param_grid,
                        scoring = roc_auc_scorer,
                        verbose=2,
                        n_jobs=-1)
ISO_grid.fit(X_train_transformed, y_train_transformed)
# Out:
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# [CV] END max_features=0.25, max_samples=100, n_estimators=100; total time=  28.2s
# [CV] END max_features=0.25, max_samples=100, n_estimators=100; total time=  28.2s
# [CV] END max_features=0.25, max_samples=100, n_estimators=100; total time=  28.4s
# [CV] END max_features=0.25, max_samples=100, n_estimators=100; total time=  28.4s
# [CV] END max_features=0.25, max_samples=100, n_estimators=100; total time=  28.6s
# [CV] END max_features=0.25, max_samples=100, n_estimators=200; total time=  52.4s
# [CV] END max_features=0.25, max_samples=100, n_estimators=200; total time=  52.5s
# [CV] END max_features=0.25, max_samples=100, n_estimators=200; total time=  52.5s
# [CV] END max_features=0.25, max_samples=100, n_estimators=200; total time=  52.5s
# [CV] END max_features=0.25, max_samples=100, n_estimators=200; total time=  52.7s
# [CV] END max_features=0.25, max_samples=100, n_estimators=300; total time= 1.3min
# [CV] END max_features=0.25, max_samples=100, n_estimators=300; total time= 1.4min
# [CV] END max_features=0.25, max_samples=100, n_estimators=300; total time= 1.2min
# [CV] END max_features=0.25, max_samples=100, n_estimators=300; total time= 1.2min
# [CV] END max_features=0.25, max_samples=100, n_estimators=300; total time= 1.2min
# [CV] END max_features=0.25, max_samples=100, n_estimators=400; total time= 1.6min
# [CV] END max_features=0.25, max_samples=100, n_estimators=400; total time= 1.6min
# [CV] END max_features=0.25, max_samples=100, n_estimators=400; total time= 1.5min
# [CV] END max_features=0.25, max_samples=100, n_estimators=400; total time= 1.5min
# [CV] END max_features=0.25, max_samples=100, n_estimators=400; total time= 1.5min
# [CV] END max_features=0.25, max_samples=100, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=100, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=100, n_estimators=500; total time= 1.9min
# [CV] END max_features=0.25, max_samples=100, n_estimators=500; total time= 1.9min
# [CV] END max_features=0.25, max_samples=100, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=100, n_estimators=600; total time= 2.3min
# [CV] END max_features=0.25, max_samples=100, n_estimators=600; total time= 2.4min
# [CV] END max_features=0.25, max_samples=100, n_estimators=600; total time= 2.4min
# [CV] END max_features=0.25, max_samples=100, n_estimators=600; total time= 2.4min
# [CV] END max_features=0.25, max_samples=100, n_estimators=600; total time= 2.3min
# [CV] END max_features=0.25, max_samples=200, n_estimators=100; total time=  20.9s
# [CV] END max_features=0.25, max_samples=100, n_estimators=700; total time= 2.5min
# [CV] END max_features=0.25, max_samples=200, n_estimators=100; total time=  16.7s
# [CV] END max_features=0.25, max_samples=100, n_estimators=700; total time= 2.6min
# [CV] END max_features=0.25, max_samples=200, n_estimators=100; total time=  18.1s
# [CV] END max_features=0.25, max_samples=200, n_estimators=100; total time=  19.2s
# [CV] END max_features=0.25, max_samples=100, n_estimators=700; total time= 2.4min
# [CV] END max_features=0.25, max_samples=200, n_estimators=100; total time=  19.3s
# [CV] END max_features=0.25, max_samples=100, n_estimators=700; total time= 2.4min
# [CV] END max_features=0.25, max_samples=200, n_estimators=200; total time=  36.8s
# [CV] END max_features=0.25, max_samples=100, n_estimators=700; total time= 2.4min
# [CV] END max_features=0.25, max_samples=200, n_estimators=200; total time=  41.4s
# [CV] END max_features=0.25, max_samples=200, n_estimators=200; total time=  37.9s
# [CV] END max_features=0.25, max_samples=200, n_estimators=200; total time=  38.1s
# [CV] END max_features=0.25, max_samples=100, n_estimators=800; total time= 2.6min
# [CV] END max_features=0.25, max_samples=200, n_estimators=200; total time=  41.6s
# [CV] END max_features=0.25, max_samples=100, n_estimators=800; total time= 2.7min
# [CV] END max_features=0.25, max_samples=200, n_estimators=300; total time= 1.1min
# [CV] END max_features=0.25, max_samples=100, n_estimators=800; total time= 2.7min
# [CV] END max_features=0.25, max_samples=100, n_estimators=800; total time= 2.6min
# [CV] END max_features=0.25, max_samples=200, n_estimators=300; total time= 1.1min
# [CV] END max_features=0.25, max_samples=200, n_estimators=300; total time= 1.3min
# [CV] END max_features=0.25, max_samples=100, n_estimators=800; total time= 2.6min
# [CV] END max_features=0.25, max_samples=200, n_estimators=300; total time= 1.3min
# [CV] END max_features=0.25, max_samples=200, n_estimators=300; total time= 1.3min
# [CV] END max_features=0.25, max_samples=200, n_estimators=400; total time= 1.7min
# [CV] END max_features=0.25, max_samples=200, n_estimators=400; total time= 1.7min
# [CV] END max_features=0.25, max_samples=200, n_estimators=400; total time= 1.7min
# [CV] END max_features=0.25, max_samples=200, n_estimators=400; total time= 1.7min
# [CV] END max_features=0.25, max_samples=200, n_estimators=400; total time= 1.8min
# [CV] END max_features=0.25, max_samples=200, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=200, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=200, n_estimators=500; total time= 1.9min
# [CV] END max_features=0.25, max_samples=200, n_estimators=500; total time= 2.1min
# [CV] END max_features=0.25, max_samples=200, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=200, n_estimators=600; total time= 2.5min
# [CV] END max_features=0.25, max_samples=200, n_estimators=600; total time= 2.5min
# [CV] END max_features=0.25, max_samples=200, n_estimators=600; total time= 2.4min
# [CV] END max_features=0.25, max_samples=200, n_estimators=600; total time= 2.4min
# [CV] END max_features=0.25, max_samples=200, n_estimators=600; total time= 2.5min
# [CV] END max_features=0.25, max_samples=300, n_estimators=100; total time=  21.8s
# [CV] END max_features=0.25, max_samples=300, n_estimators=100; total time=  21.5s
# [CV] END max_features=0.25, max_samples=200, n_estimators=700; total time= 2.6min
# [CV] END max_features=0.25, max_samples=300, n_estimators=100; total time=  16.4s
# [CV] END max_features=0.25, max_samples=300, n_estimators=100; total time=  16.9s
# [CV] END max_features=0.25, max_samples=200, n_estimators=700; total time= 2.7min
# [CV] END max_features=0.25, max_samples=300, n_estimators=100; total time=  21.2s
# [CV] END max_features=0.25, max_samples=200, n_estimators=700; total time= 2.5min
# [CV] END max_features=0.25, max_samples=200, n_estimators=700; total time= 2.5min
# [CV] END max_features=0.25, max_samples=200, n_estimators=700; total time= 2.5min
# [CV] END max_features=0.25, max_samples=300, n_estimators=200; total time=  40.0s
# [CV] END max_features=0.25, max_samples=300, n_estimators=200; total time=  41.1s
# [CV] END max_features=0.25, max_samples=300, n_estimators=200; total time=  42.8s
# [CV] END max_features=0.25, max_samples=200, n_estimators=800; total time= 2.7min
# [CV] END max_features=0.25, max_samples=300, n_estimators=200; total time=  46.0s
# [CV] END max_features=0.25, max_samples=200, n_estimators=800; total time= 2.8min
# [CV] END max_features=0.25, max_samples=300, n_estimators=200; total time=  44.9s
# [CV] END max_features=0.25, max_samples=200, n_estimators=800; total time= 2.7min
# [CV] END max_features=0.25, max_samples=200, n_estimators=800; total time= 2.7min
# [CV] END max_features=0.25, max_samples=300, n_estimators=300; total time= 1.1min
# [CV] END max_features=0.25, max_samples=300, n_estimators=300; total time= 1.2min
# [CV] END max_features=0.25, max_samples=300, n_estimators=300; total time= 1.3min
# [CV] END max_features=0.25, max_samples=300, n_estimators=300; total time= 1.3min
# [CV] END max_features=0.25, max_samples=300, n_estimators=300; total time= 1.3min
# [CV] END max_features=0.25, max_samples=200, n_estimators=800; total time= 2.9min
# [CV] END max_features=0.25, max_samples=300, n_estimators=400; total time= 1.6min
# [CV] END max_features=0.25, max_samples=300, n_estimators=400; total time= 1.6min
# [CV] END max_features=0.25, max_samples=300, n_estimators=400; total time= 1.6min
# [CV] END max_features=0.25, max_samples=300, n_estimators=400; total time= 1.7min
# [CV] END max_features=0.25, max_samples=300, n_estimators=400; total time= 1.7min
# [CV] END max_features=0.25, max_samples=300, n_estimators=500; total time= 1.9min
# [CV] END max_features=0.25, max_samples=300, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=300, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=300, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=300, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=300, n_estimators=600; total time= 2.3min
# [CV] END max_features=0.25, max_samples=300, n_estimators=600; total time= 2.3min
# [CV] END max_features=0.25, max_samples=300, n_estimators=600; total time= 2.4min
# [CV] END max_features=0.25, max_samples=300, n_estimators=600; total time= 2.3min
# [CV] END max_features=0.25, max_samples=300, n_estimators=600; total time= 2.4min
# [CV] END max_features=0.25, max_samples=400, n_estimators=100; total time=  20.8s
# [CV] END max_features=0.25, max_samples=300, n_estimators=700; total time= 2.6min
# [CV] END max_features=0.25, max_samples=400, n_estimators=100; total time=  20.7s
# [CV] END max_features=0.25, max_samples=300, n_estimators=700; total time= 2.4min
# [CV] END max_features=0.25, max_samples=400, n_estimators=100; total time=  15.8s
# [CV] END max_features=0.25, max_samples=400, n_estimators=100; total time=  17.5s
# [CV] END max_features=0.25, max_samples=400, n_estimators=100; total time=  20.0s
# [CV] END max_features=0.25, max_samples=300, n_estimators=700; total time= 2.3min
# [CV] END max_features=0.25, max_samples=300, n_estimators=700; total time= 2.4min
# [CV] END max_features=0.25, max_samples=300, n_estimators=700; total time= 2.4min
# [CV] END max_features=0.25, max_samples=400, n_estimators=200; total time=  38.4s
# [CV] END max_features=0.25, max_samples=400, n_estimators=200; total time=  39.0s
# [CV] END max_features=0.25, max_samples=400, n_estimators=200; total time=  41.8s
# [CV] END max_features=0.25, max_samples=400, n_estimators=200; total time=  40.1s
# [CV] END max_features=0.25, max_samples=300, n_estimators=800; total time= 2.6min
# [CV] END max_features=0.25, max_samples=400, n_estimators=200; total time=  42.2s
# [CV] END max_features=0.25, max_samples=300, n_estimators=800; total time= 2.8min
# [CV] END max_features=0.25, max_samples=400, n_estimators=300; total time= 1.0min
# [CV] END max_features=0.25, max_samples=400, n_estimators=300; total time= 1.1min
# [CV] END max_features=0.25, max_samples=300, n_estimators=800; total time= 2.7min
# [CV] END max_features=0.25, max_samples=300, n_estimators=800; total time= 2.6min
# [CV] END max_features=0.25, max_samples=400, n_estimators=300; total time= 1.2min
# [CV] END max_features=0.25, max_samples=400, n_estimators=300; total time= 1.2min
# [CV] END max_features=0.25, max_samples=400, n_estimators=300; total time= 1.2min
# [CV] END max_features=0.25, max_samples=300, n_estimators=800; total time= 2.9min
# [CV] END max_features=0.25, max_samples=400, n_estimators=400; total time= 1.6min
# [CV] END max_features=0.25, max_samples=400, n_estimators=400; total time= 1.6min
# [CV] END max_features=0.25, max_samples=400, n_estimators=400; total time= 1.6min
# [CV] END max_features=0.25, max_samples=400, n_estimators=400; total time= 1.6min
# [CV] END max_features=0.25, max_samples=400, n_estimators=400; total time= 1.7min
# [CV] END max_features=0.25, max_samples=400, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=400, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=400, n_estimators=500; total time= 1.9min
# [CV] END max_features=0.25, max_samples=400, n_estimators=500; total time= 1.9min
# [CV] END max_features=0.25, max_samples=400, n_estimators=500; total time= 2.0min
# [CV] END max_features=0.25, max_samples=400, n_estimators=600; total time= 2.4min
# [CV] END max_features=0.25, max_samples=400, n_estimators=600; total time= 2.4min
# [CV] END max_features=0.25, max_samples=400, n_estimators=600; total time= 2.2min
# [CV] END max_features=0.25, max_samples=400, n_estimators=600; total time= 2.4min
# [CV] END max_features=0.25, max_samples=400, n_estimators=600; total time= 2.3min
# [CV] END max_features=0.5, max_samples=100, n_estimators=100; total time=  29.8s
# [CV] END max_features=0.5, max_samples=100, n_estimators=100; total time=  24.9s
# [CV] END max_features=0.25, max_samples=400, n_estimators=700; total time= 2.7min
# [CV] END max_features=0.25, max_samples=400, n_estimators=700; total time= 2.5min
# [CV] END max_features=0.5, max_samples=100, n_estimators=100; total time=  23.6s
# [CV] END max_features=0.5, max_samples=100, n_estimators=100; total time=  25.8s
# [CV] END max_features=0.5, max_samples=100, n_estimators=100; total time=  26.2s
# [CV] END max_features=0.25, max_samples=400, n_estimators=700; total time= 2.5min
# [CV] END max_features=0.25, max_samples=400, n_estimators=700; total time= 2.5min
# [CV] END max_features=0.25, max_samples=400, n_estimators=700; total time= 2.5min
# [CV] END max_features=0.5, max_samples=100, n_estimators=200; total time=  56.3s
# [CV] END max_features=0.25, max_samples=400, n_estimators=800; total time= 2.8min
# [CV] END max_features=0.5, max_samples=100, n_estimators=200; total time=  56.5s
# [CV] END max_features=0.25, max_samples=400, n_estimators=800; total time= 2.9min
# [CV] END max_features=0.5, max_samples=100, n_estimators=200; total time= 1.1min
# [CV] END max_features=0.5, max_samples=100, n_estimators=200; total time= 1.1min
# [CV] END max_features=0.5, max_samples=100, n_estimators=200; total time= 1.1min
# [CV] END max_features=0.25, max_samples=400, n_estimators=800; total time= 3.1min
# [CV] END max_features=0.5, max_samples=100, n_estimators=300; total time= 1.7min
# [CV] END max_features=0.25, max_samples=400, n_estimators=800; total time= 3.1min
# [CV] END max_features=0.5, max_samples=100, n_estimators=300; total time= 1.7min
# [CV] END max_features=0.25, max_samples=400, n_estimators=800; total time= 3.3min
# [CV] END max_features=0.5, max_samples=100, n_estimators=300; total time= 2.0min
# [CV] END max_features=0.5, max_samples=100, n_estimators=300; total time= 2.0min
# [CV] END max_features=0.5, max_samples=100, n_estimators=300; total time= 2.1min
# [CV] END max_features=0.5, max_samples=100, n_estimators=400; total time= 2.6min
# [CV] END max_features=0.5, max_samples=100, n_estimators=400; total time= 2.4min
# [CV] END max_features=0.5, max_samples=100, n_estimators=400; total time= 2.5min
# [CV] END max_features=0.5, max_samples=100, n_estimators=400; total time= 2.6min
# [CV] END max_features=0.5, max_samples=100, n_estimators=400; total time= 2.6min
# [CV] END max_features=0.5, max_samples=100, n_estimators=500; total time= 3.0min
# [CV] END max_features=0.5, max_samples=100, n_estimators=500; total time= 3.0min
# [CV] END max_features=0.5, max_samples=100, n_estimators=500; total time= 3.0min
# [CV] END max_features=0.5, max_samples=100, n_estimators=500; total time= 3.1min
# [CV] END max_features=0.5, max_samples=100, n_estimators=500; total time= 3.3min
# [CV] END max_features=0.5, max_samples=100, n_estimators=600; total time= 3.6min
# [CV] END max_features=0.5, max_samples=100, n_estimators=600; total time= 3.7min
# [CV] END max_features=0.5, max_samples=100, n_estimators=600; total time= 3.6min
# [CV] END max_features=0.5, max_samples=100, n_estimators=600; total time= 3.7min
# [CV] END max_features=0.5, max_samples=100, n_estimators=600; total time= 3.6min
# [CV] END max_features=0.5, max_samples=200, n_estimators=100; total time=  27.7s
# [CV] END max_features=0.5, max_samples=200, n_estimators=100; total time=  27.4s
# [CV] END max_features=0.5, max_samples=100, n_estimators=700; total time= 3.9min
# [CV] END max_features=0.5, max_samples=100, n_estimators=700; total time= 3.7min
# [CV] END max_features=0.5, max_samples=200, n_estimators=100; total time=  25.3s
# [CV] END max_features=0.5, max_samples=200, n_estimators=100; total time=  25.4s
# [CV] END max_features=0.5, max_samples=200, n_estimators=100; total time=  27.9s
# [CV] END max_features=0.5, max_samples=100, n_estimators=700; total time= 3.6min
# [CV] END max_features=0.5, max_samples=100, n_estimators=700; total time= 3.6min
# [CV] END max_features=0.5, max_samples=100, n_estimators=700; total time= 3.7min
# [CV] END max_features=0.5, max_samples=200, n_estimators=200; total time=  59.1s
# [CV] END max_features=0.5, max_samples=200, n_estimators=200; total time=  55.6s
# [CV] END max_features=0.5, max_samples=200, n_estimators=200; total time=  55.4s
# [CV] END max_features=0.5, max_samples=200, n_estimators=200; total time= 1.1min
# [CV] END max_features=0.5, max_samples=100, n_estimators=800; total time= 4.1min
# [CV] END max_features=0.5, max_samples=100, n_estimators=800; total time= 3.8min
# [CV] END max_features=0.5, max_samples=200, n_estimators=200; total time= 1.2min
# [CV] END max_features=0.5, max_samples=200, n_estimators=300; total time= 1.7min
# [CV] END max_features=0.5, max_samples=100, n_estimators=800; total time= 3.8min
# [CV] END max_features=0.5, max_samples=200, n_estimators=300; total time= 1.9min
# [CV] END max_features=0.5, max_samples=100, n_estimators=800; total time= 4.1min
# [CV] END max_features=0.5, max_samples=200, n_estimators=300; total time= 1.8min
# [CV] END max_features=0.5, max_samples=200, n_estimators=300; total time= 2.0min
# [CV] END max_features=0.5, max_samples=200, n_estimators=300; total time= 2.0min
# [CV] END max_features=0.5, max_samples=100, n_estimators=800; total time= 4.2min
# [CV] END max_features=0.5, max_samples=200, n_estimators=400; total time= 2.6min
# [CV] END max_features=0.5, max_samples=200, n_estimators=400; total time= 2.6min
# /home/stu15/s10/mjh9122/miniconda3/envs/fraud/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END max_features=0.5, max_samples=200, n_estimators=400; total time= 2.6min
# [CV] END max_features=0.5, max_samples=200, n_estimators=400; total time= 2.6min
# [CV] END max_features=0.5, max_samples=200, n_estimators=400; total time= 2.7min
# [CV] END max_features=0.5, max_samples=200, n_estimators=500; total time= 3.2min
# [CV] END max_features=0.5, max_samples=200, n_estimators=500; total time= 3.0min
# [CV] END max_features=0.5, max_samples=200, n_estimators=500; total time= 3.0min
# [CV] END max_features=0.5, max_samples=200, n_estimators=500; total time= 3.1min
# [CV] END max_features=0.5, max_samples=200, n_estimators=500; total time= 3.2min
# [CV] END max_features=0.5, max_samples=200, n_estimators=600; total time= 3.9min
# [CV] END max_features=0.5, max_samples=200, n_estimators=600; total time= 3.6min
# [CV] END max_features=0.5, max_samples=200, n_estimators=600; total time= 3.7min
# [CV] END max_features=0.5, max_samples=200, n_estimators=600; total time= 3.7min
# [CV] END max_features=0.5, max_samples=200, n_estimators=600; total time= 3.9min
# [CV] END max_features=0.5, max_samples=300, n_estimators=100; total time=  29.8s
# [CV] END max_features=0.5, max_samples=200, n_estimators=700; total time= 4.1min
# [CV] END max_features=0.5, max_samples=300, n_estimators=100; total time=  24.6s
# [CV] END max_features=0.5, max_samples=300, n_estimators=100; total time=  24.9s
# [CV] END max_features=0.5, max_samples=200, n_estimators=700; total time= 3.8min
# [CV] END max_features=0.5, max_samples=300, n_estimators=100; total time=  24.1s
# [CV] END max_features=0.5, max_samples=300, n_estimators=100; total time=  31.5s
# [CV] END max_features=0.5, max_samples=200, n_estimators=700; total time= 3.9min
# [CV] END max_features=0.5, max_samples=200, n_estimators=700; total time= 3.8min
# [CV] END max_features=0.5, max_samples=200, n_estimators=700; total time= 3.9min
# [CV] END max_features=0.5, max_samples=300, n_estimators=200; total time=  56.4s
# [CV] END max_features=0.5, max_samples=300, n_estimators=200; total time= 1.0min
# [CV] END max_features=0.5, max_samples=300, n_estimators=200; total time= 1.0min
# [CV] END max_features=0.5, max_samples=300, n_estimators=200; total time= 1.1min
# [CV] END max_features=0.5, max_samples=200, n_estimators=800; total time= 4.6min
# [CV] END max_features=0.5, max_samples=200, n_estimators=800; total time= 4.3min
# [CV] END max_features=0.5, max_samples=300, n_estimators=200; total time= 1.2min
# [CV] END max_features=0.5, max_samples=200, n_estimators=800; total time= 4.1min
# [CV] END max_features=0.5, max_samples=200, n_estimators=800; total time= 4.1min
# [CV] END max_features=0.5, max_samples=300, n_estimators=300; total time= 1.9min
# [CV] END max_features=0.5, max_samples=300, n_estimators=300; total time= 1.8min
# [CV] END max_features=0.5, max_samples=300, n_estimators=300; total time= 1.9min
# [CV] END max_features=0.5, max_samples=300, n_estimators=300; total time= 2.0min
# [CV] END max_features=0.5, max_samples=300, n_estimators=300; total time= 2.0min
# [CV] END max_features=0.5, max_samples=200, n_estimators=800; total time= 4.2min
# [CV] END max_features=0.5, max_samples=300, n_estimators=400; total time= 2.6min
# [CV] END max_features=0.5, max_samples=300, n_estimators=400; total time= 2.6min
# [CV] END max_features=0.5, max_samples=300, n_estimators=400; total time= 2.7min
# [CV] END max_features=0.5, max_samples=300, n_estimators=400; total time= 2.7min
# [CV] END max_features=0.5, max_samples=300, n_estimators=400; total time= 2.8min
# [CV] END max_features=0.5, max_samples=300, n_estimators=500; total time= 3.3min
# [CV] END max_features=0.5, max_samples=300, n_estimators=500; total time= 3.2min
# [CV] END max_features=0.5, max_samples=300, n_estimators=500; total time= 3.2min
# [CV] END max_features=0.5, max_samples=300, n_estimators=500; total time= 3.3min
# [CV] END max_features=0.5, max_samples=300, n_estimators=500; total time= 3.3min
# [CV] END max_features=0.5, max_samples=300, n_estimators=600; total time= 3.9min
# [CV] END max_features=0.5, max_samples=300, n_estimators=600; total time= 4.0min
# [CV] END max_features=0.5, max_samples=300, n_estimators=600; total time= 3.9min
# [CV] END max_features=0.5, max_samples=300, n_estimators=600; total time= 3.9min
# [CV] END max_features=0.5, max_samples=300, n_estimators=600; total time= 3.7min
# [CV] END max_features=0.5, max_samples=400, n_estimators=100; total time=  31.0s
# [CV] END max_features=0.5, max_samples=300, n_estimators=700; total time= 4.0min
# [CV] END max_features=0.5, max_samples=400, n_estimators=100; total time=  27.0s
# [CV] END max_features=0.5, max_samples=400, n_estimators=100; total time=  22.5s
# [CV] END max_features=0.5, max_samples=300, n_estimators=700; total time= 3.8min
# [CV] END max_features=0.5, max_samples=400, n_estimators=100; total time=  25.8s
# [CV] END max_features=0.5, max_samples=400, n_estimators=100; total time=  29.8s
# [CV] END max_features=0.5, max_samples=300, n_estimators=700; total time= 3.8min
# [CV] END max_features=0.5, max_samples=300, n_estimators=700; total time= 3.8min
# [CV] END max_features=0.5, max_samples=300, n_estimators=700; total time= 3.8min
# [CV] END max_features=0.5, max_samples=400, n_estimators=200; total time=  56.6s
# [CV] END max_features=0.5, max_samples=400, n_estimators=200; total time= 1.0min
# [CV] END max_features=0.5, max_samples=400, n_estimators=200; total time=  59.3s
# [CV] END max_features=0.5, max_samples=400, n_estimators=200; total time= 1.0min
# [CV] END max_features=0.5, max_samples=300, n_estimators=800; total time= 4.1min
# [CV] END max_features=0.5, max_samples=300, n_estimators=800; total time= 4.1min
# [CV] END max_features=0.5, max_samples=400, n_estimators=200; total time= 1.2min
# [CV] END max_features=0.5, max_samples=300, n_estimators=800; total time= 4.0min
# [CV] END max_features=0.5, max_samples=400, n_estimators=300; total time= 1.7min
# [CV] END max_features=0.5, max_samples=400, n_estimators=300; total time= 1.6min
# [CV] END max_features=0.5, max_samples=300, n_estimators=800; total time= 4.1min
# [CV] END max_features=0.5, max_samples=400, n_estimators=300; total time= 1.9min
# [CV] END max_features=0.5, max_samples=400, n_estimators=300; total time= 2.0min
# [CV] END max_features=0.5, max_samples=400, n_estimators=300; total time= 1.9min
# [CV] END max_features=0.5, max_samples=300, n_estimators=800; total time= 4.5min
# [CV] END max_features=0.5, max_samples=400, n_estimators=400; total time= 2.6min
# [CV] END max_features=0.5, max_samples=400, n_estimators=400; total time= 2.6min
# [CV] END max_features=0.5, max_samples=400, n_estimators=400; total time= 2.6min
# [CV] END max_features=0.5, max_samples=400, n_estimators=400; total time= 2.5min
# [CV] END max_features=0.5, max_samples=400, n_estimators=400; total time= 2.8min
# [CV] END max_features=0.5, max_samples=400, n_estimators=500; total time= 3.1min
# [CV] END max_features=0.5, max_samples=400, n_estimators=500; total time= 3.2min
# [CV] END max_features=0.5, max_samples=400, n_estimators=500; total time= 3.2min
# [CV] END max_features=0.5, max_samples=400, n_estimators=500; total time= 3.0min
# [CV] END max_features=0.5, max_samples=400, n_estimators=500; total time= 3.3min
# [CV] END max_features=0.5, max_samples=400, n_estimators=600; total time= 3.9min
# [CV] END max_features=0.5, max_samples=400, n_estimators=600; total time= 3.8min
# [CV] END max_features=0.5, max_samples=400, n_estimators=600; total time= 3.8min
# [CV] END max_features=0.5, max_samples=400, n_estimators=600; total time= 3.7min
# [CV] END max_features=0.5, max_samples=400, n_estimators=600; total time= 3.8min
# [CV] END max_features=0.5, max_samples=400, n_estimators=700; total time= 4.2min
# [CV] END max_features=0.75, max_samples=100, n_estimators=100; total time=  34.0s
# [CV] END max_features=0.75, max_samples=100, n_estimators=100; total time=  31.7s
# [CV] END max_features=0.75, max_samples=100, n_estimators=100; total time=  27.6s
# [CV] END max_features=0.5, max_samples=400, n_estimators=700; total time= 3.8min
# [CV] END max_features=0.75, max_samples=100, n_estimators=100; total time=  27.8s
# [CV] END max_features=0.75, max_samples=100, n_estimators=100; total time=  32.9s
# [CV] END max_features=0.5, max_samples=400, n_estimators=700; total time= 3.8min
# [CV] END max_features=0.5, max_samples=400, n_estimators=700; total time= 3.8min
# [CV] END max_features=0.5, max_samples=400, n_estimators=700; total time= 4.0min
# [CV] END max_features=0.5, max_samples=400, n_estimators=800; total time= 4.2min
# [CV] END max_features=0.75, max_samples=100, n_estimators=200; total time= 1.3min
# [CV] END max_features=0.75, max_samples=100, n_estimators=200; total time= 1.3min
# [CV] END max_features=0.75, max_samples=100, n_estimators=200; total time= 1.3min
# [CV] END max_features=0.5, max_samples=400, n_estimators=800; total time= 4.2min
# [CV] END max_features=0.75, max_samples=100, n_estimators=200; total time= 1.6min
# [CV] END max_features=0.75, max_samples=100, n_estimators=200; total time= 1.7min
# [CV] END max_features=0.5, max_samples=400, n_estimators=800; total time= 4.4min
# [CV] END max_features=0.75, max_samples=100, n_estimators=300; total time= 2.3min
# [CV] END max_features=0.75, max_samples=100, n_estimators=300; total time= 2.2min
# [CV] END max_features=0.5, max_samples=400, n_estimators=800; total time= 4.4min
# [CV] END max_features=0.5, max_samples=400, n_estimators=800; total time= 4.5min
# [CV] END max_features=0.75, max_samples=100, n_estimators=300; total time= 2.7min
# [CV] END max_features=0.75, max_samples=100, n_estimators=300; total time= 2.7min
# [CV] END max_features=0.75, max_samples=100, n_estimators=300; total time= 2.7min
# [CV] END max_features=0.75, max_samples=100, n_estimators=400; total time= 3.5min
# [CV] END max_features=0.75, max_samples=100, n_estimators=400; total time= 3.5min
# [CV] END max_features=0.75, max_samples=100, n_estimators=400; total time= 3.2min
# [CV] END max_features=0.75, max_samples=100, n_estimators=400; total time= 3.4min
# [CV] END max_features=0.75, max_samples=100, n_estimators=400; total time= 3.5min
# [CV] END max_features=0.75, max_samples=100, n_estimators=500; total time= 4.0min
# [CV] END max_features=0.75, max_samples=100, n_estimators=500; total time= 4.2min
# [CV] END max_features=0.75, max_samples=100, n_estimators=500; total time= 4.2min
# [CV] END max_features=0.75, max_samples=100, n_estimators=500; total time= 3.9min
# [CV] END max_features=0.75, max_samples=100, n_estimators=500; total time= 4.5min
# [CV] END max_features=0.75, max_samples=100, n_estimators=600; total time= 5.0min
# [CV] END max_features=0.75, max_samples=100, n_estimators=600; total time= 5.3min
# [CV] END max_features=0.75, max_samples=100, n_estimators=600; total time= 5.2min
# [CV] END max_features=0.75, max_samples=100, n_estimators=600; total time= 5.5min
# [CV] END max_features=0.75, max_samples=100, n_estimators=600; total time= 5.3min
# [CV] END max_features=0.75, max_samples=200, n_estimators=100; total time=  45.9s
# [CV] END max_features=0.75, max_samples=200, n_estimators=100; total time=  44.7s
# [CV] END max_features=0.75, max_samples=100, n_estimators=700; total time= 5.6min
# [CV] END max_features=0.75, max_samples=100, n_estimators=700; total time= 5.7min
# [CV] END max_features=0.75, max_samples=200, n_estimators=100; total time=  34.5s
# [CV] END max_features=0.75, max_samples=200, n_estimators=100; total time=  35.0s
# [CV] END max_features=0.75, max_samples=200, n_estimators=100; total time=  42.9s
# [CV] END max_features=0.75, max_samples=100, n_estimators=700; total time= 5.5min
# [CV] END max_features=0.75, max_samples=100, n_estimators=700; total time= 5.6min
# [CV] END max_features=0.75, max_samples=100, n_estimators=700; total time= 5.5min
# [CV] END max_features=0.75, max_samples=200, n_estimators=200; total time= 1.2min
# [CV] END max_features=0.75, max_samples=200, n_estimators=200; total time= 1.4min
# [CV] END max_features=0.75, max_samples=200, n_estimators=200; total time= 1.3min
# [CV] END max_features=0.75, max_samples=200, n_estimators=200; total time= 1.3min
# [CV] END max_features=0.75, max_samples=100, n_estimators=800; total time= 6.4min
# [CV] END max_features=0.75, max_samples=200, n_estimators=200; total time= 1.5min
# [CV] END max_features=0.75, max_samples=100, n_estimators=800; total time= 5.9min
# [CV] END max_features=0.75, max_samples=100, n_estimators=800; total time= 5.7min
# [CV] END max_features=0.75, max_samples=200, n_estimators=300; total time= 2.2min
# [CV] END max_features=0.75, max_samples=100, n_estimators=800; total time= 5.7min
# [CV] END max_features=0.75, max_samples=200, n_estimators=300; total time= 2.2min
# [CV] END max_features=0.75, max_samples=200, n_estimators=300; total time= 2.1min
# [CV] END max_features=0.75, max_samples=200, n_estimators=300; total time= 2.5min
# [CV] END max_features=0.75, max_samples=200, n_estimators=300; total time= 2.4min
# [CV] END max_features=0.75, max_samples=100, n_estimators=800; total time= 6.1min
# [CV] END max_features=0.75, max_samples=200, n_estimators=400; total time= 3.5min
# [CV] END max_features=0.75, max_samples=200, n_estimators=400; total time= 3.4min
# [CV] END max_features=0.75, max_samples=200, n_estimators=400; total time= 3.4min
# [CV] END max_features=0.75, max_samples=200, n_estimators=400; total time= 3.6min
# [CV] END max_features=0.75, max_samples=200, n_estimators=400; total time= 3.5min
# [CV] END max_features=0.75, max_samples=200, n_estimators=500; total time= 4.2min
# [CV] END max_features=0.75, max_samples=200, n_estimators=500; total time= 4.0min
# [CV] END max_features=0.75, max_samples=200, n_estimators=500; total time= 4.3min
# [CV] END max_features=0.75, max_samples=200, n_estimators=500; total time= 4.3min
# [CV] END max_features=0.75, max_samples=200, n_estimators=500; total time= 4.2min
# [CV] END max_features=0.75, max_samples=200, n_estimators=600; total time= 5.4min
# [CV] END max_features=0.75, max_samples=200, n_estimators=600; total time= 5.0min
# [CV] END max_features=0.75, max_samples=200, n_estimators=600; total time= 4.9min
# [CV] END max_features=0.75, max_samples=200, n_estimators=600; total time= 4.9min
# [CV] END max_features=0.75, max_samples=200, n_estimators=600; total time= 4.9min
# [CV] END max_features=0.75, max_samples=300, n_estimators=100; total time=  33.9s
# [CV] END max_features=0.75, max_samples=300, n_estimators=100; total time=  29.0s
# [CV] END max_features=0.75, max_samples=300, n_estimators=100; total time=  29.5s
# [CV] END max_features=0.75, max_samples=300, n_estimators=100; total time=  30.6s
# [CV] END max_features=0.75, max_samples=200, n_estimators=700; total time= 5.2min
# [CV] END max_features=0.75, max_samples=200, n_estimators=700; total time= 5.4min
# [CV] END max_features=0.75, max_samples=300, n_estimators=100; total time=  37.8s
# [CV] END max_features=0.75, max_samples=200, n_estimators=700; total time= 5.1min
# [CV] END max_features=0.75, max_samples=200, n_estimators=700; total time= 5.1min
# [CV] END max_features=0.75, max_samples=200, n_estimators=700; total time= 5.1min
# [CV] END max_features=0.75, max_samples=300, n_estimators=200; total time= 1.3min
# [CV] END max_features=0.75, max_samples=300, n_estimators=200; total time= 1.3min
# [CV] END max_features=0.75, max_samples=300, n_estimators=200; total time= 1.3min
# [CV] END max_features=0.75, max_samples=200, n_estimators=800; total time= 5.6min
# [CV] END max_features=0.75, max_samples=300, n_estimators=200; total time= 1.4min
# [CV] END max_features=0.75, max_samples=200, n_estimators=800; total time= 5.6min
# [CV] END max_features=0.75, max_samples=300, n_estimators=200; total time= 1.8min
# [CV] END max_features=0.75, max_samples=200, n_estimators=800; total time= 5.3min
# [CV] END max_features=0.75, max_samples=200, n_estimators=800; total time= 5.2min
# [CV] END max_features=0.75, max_samples=300, n_estimators=300; total time= 2.5min
# [CV] END max_features=0.75, max_samples=300, n_estimators=300; total time= 2.3min
# [CV] END max_features=0.75, max_samples=200, n_estimators=800; total time= 5.3min
# [CV] END max_features=0.75, max_samples=300, n_estimators=300; total time= 2.6min
# [CV] END max_features=0.75, max_samples=300, n_estimators=300; total time= 2.7min
# [CV] END max_features=0.75, max_samples=300, n_estimators=300; total time= 2.6min
# [CV] END max_features=0.75, max_samples=300, n_estimators=400; total time= 3.5min
# [CV] END max_features=0.75, max_samples=300, n_estimators=400; total time= 3.6min
# [CV] END max_features=0.75, max_samples=300, n_estimators=400; total time= 3.7min
# [CV] END max_features=0.75, max_samples=300, n_estimators=400; total time= 3.6min
# [CV] END max_features=0.75, max_samples=300, n_estimators=400; total time= 3.7min
# [CV] END max_features=0.75, max_samples=300, n_estimators=500; total time= 4.3min
# [CV] END max_features=0.75, max_samples=300, n_estimators=500; total time= 4.3min
# [CV] END max_features=0.75, max_samples=300, n_estimators=500; total time= 4.4min
# [CV] END max_features=0.75, max_samples=300, n_estimators=500; total time= 4.2min
# [CV] END max_features=0.75, max_samples=300, n_estimators=500; total time= 4.4min
# [CV] END max_features=0.75, max_samples=300, n_estimators=600; total time= 5.5min
# [CV] END max_features=0.75, max_samples=300, n_estimators=600; total time= 5.5min
# [CV] END max_features=0.75, max_samples=300, n_estimators=600; total time= 5.2min
# [CV] END max_features=0.75, max_samples=300, n_estimators=600; total time= 5.0min
# [CV] END max_features=0.75, max_samples=300, n_estimators=600; total time= 5.3min
# [CV] END max_features=0.75, max_samples=400, n_estimators=100; total time=  43.1s
# [CV] END max_features=0.75, max_samples=400, n_estimators=100; total time=  33.0s
# [CV] END max_features=0.75, max_samples=300, n_estimators=700; total time= 5.4min
# [CV] END max_features=0.75, max_samples=400, n_estimators=100; total time=  30.1s
# [CV] END max_features=0.75, max_samples=300, n_estimators=700; total time= 5.4min
# [CV] END max_features=0.75, max_samples=400, n_estimators=100; total time=  32.7s
# [CV] END max_features=0.75, max_samples=400, n_estimators=100; total time=  37.4s
# [CV] END max_features=0.75, max_samples=300, n_estimators=700; total time= 5.1min
# [CV] END max_features=0.75, max_samples=300, n_estimators=700; total time= 5.2min
# [CV] END max_features=0.75, max_samples=300, n_estimators=700; total time= 5.2min
# [CV] END max_features=0.75, max_samples=400, n_estimators=200; total time= 1.2min
# [CV] END max_features=0.75, max_samples=400, n_estimators=200; total time= 1.3min
# [CV] END max_features=0.75, max_samples=400, n_estimators=200; total time= 1.4min
# [CV] END max_features=0.75, max_samples=400, n_estimators=200; total time= 1.4min
# [CV] END max_features=0.75, max_samples=300, n_estimators=800; total time= 5.5min
# [CV] END max_features=0.75, max_samples=300, n_estimators=800; total time= 6.0min
# [CV] END max_features=0.75, max_samples=400, n_estimators=200; total time= 1.7min
# [CV] END max_features=0.75, max_samples=300, n_estimators=800; total time= 5.3min
# [CV] END max_features=0.75, max_samples=300, n_estimators=800; total time= 5.4min
# [CV] END max_features=0.75, max_samples=400, n_estimators=300; total time= 2.3min
# [CV] END max_features=0.75, max_samples=400, n_estimators=300; total time= 2.4min
# [CV] END max_features=0.75, max_samples=400, n_estimators=300; total time= 2.5min
# [CV] END max_features=0.75, max_samples=400, n_estimators=300; total time= 2.6min
# [CV] END max_features=0.75, max_samples=400, n_estimators=300; total time= 2.5min
# [CV] END max_features=0.75, max_samples=300, n_estimators=800; total time= 6.0min
# [CV] END max_features=0.75, max_samples=400, n_estimators=400; total time= 3.4min
# [CV] END max_features=0.75, max_samples=400, n_estimators=400; total time= 3.5min
# [CV] END max_features=0.75, max_samples=400, n_estimators=400; total time= 3.6min
# [CV] END max_features=0.75, max_samples=400, n_estimators=400; total time= 3.4min
# [CV] END max_features=0.75, max_samples=400, n_estimators=400; total time= 3.8min
# [CV] END max_features=0.75, max_samples=400, n_estimators=500; total time= 4.2min
# [CV] END max_features=0.75, max_samples=400, n_estimators=500; total time= 4.4min
# [CV] END max_features=0.75, max_samples=400, n_estimators=500; total time= 3.8min
# [CV] END max_features=0.75, max_samples=400, n_estimators=500; total time= 4.1min
# [CV] END max_features=0.75, max_samples=400, n_estimators=500; total time= 4.6min
# [CV] END max_features=0.75, max_samples=400, n_estimators=600; total time= 5.2min
# [CV] END max_features=0.75, max_samples=400, n_estimators=600; total time= 5.1min
# [CV] END max_features=0.75, max_samples=400, n_estimators=600; total time= 5.0min
# [CV] END max_features=0.75, max_samples=400, n_estimators=600; total time= 5.2min
# [CV] END max_features=0.75, max_samples=400, n_estimators=600; total time= 5.1min
# [CV] END max_features=1.0, max_samples=100, n_estimators=100; total time=  15.4s
# [CV] END max_features=1.0, max_samples=100, n_estimators=100; total time=  17.4s
# [CV] END max_features=0.75, max_samples=400, n_estimators=700; total time= 5.4min
# [CV] END max_features=1.0, max_samples=100, n_estimators=100; total time=  16.5s
# [CV] END max_features=1.0, max_samples=100, n_estimators=100; total time=  17.2s
# [CV] END max_features=1.0, max_samples=100, n_estimators=100; total time=  15.2s
# [CV] END max_features=0.75, max_samples=400, n_estimators=700; total time= 4.9min
# [CV] END max_features=1.0, max_samples=100, n_estimators=200; total time=  36.6s
# [CV] END max_features=1.0, max_samples=100, n_estimators=200; total time=  35.1s
# [CV] END max_features=0.75, max_samples=400, n_estimators=700; total time= 4.6min
# [CV] END max_features=0.75, max_samples=400, n_estimators=700; total time= 4.8min
# [CV] END max_features=0.75, max_samples=400, n_estimators=700; total time= 4.8min
# [CV] END max_features=1.0, max_samples=100, n_estimators=200; total time=  32.7s
# [CV] END max_features=1.0, max_samples=100, n_estimators=200; total time=  32.9s
# [CV] END max_features=0.75, max_samples=400, n_estimators=800; total time= 4.8min
# [CV] END max_features=1.0, max_samples=100, n_estimators=200; total time=  33.1s
# [CV] END max_features=1.0, max_samples=100, n_estimators=300; total time=  47.9s
# [CV] END max_features=1.0, max_samples=100, n_estimators=300; total time=  49.4s
# [CV] END max_features=0.75, max_samples=400, n_estimators=800; total time= 4.3min
# [CV] END max_features=1.0, max_samples=100, n_estimators=300; total time=  50.8s
# [CV] END max_features=1.0, max_samples=100, n_estimators=300; total time=  49.2s
# [CV] END max_features=1.0, max_samples=100, n_estimators=300; total time=  50.1s
# [CV] END max_features=1.0, max_samples=100, n_estimators=400; total time= 1.1min
# [CV] END max_features=0.75, max_samples=400, n_estimators=800; total time= 4.0min
# [CV] END max_features=0.75, max_samples=400, n_estimators=800; total time= 3.7min
# [CV] END max_features=1.0, max_samples=100, n_estimators=400; total time= 1.0min
# [CV] END max_features=1.0, max_samples=100, n_estimators=400; total time= 1.1min
# [CV] END max_features=0.75, max_samples=400, n_estimators=800; total time= 3.6min
# [CV] END max_features=1.0, max_samples=100, n_estimators=400; total time= 1.1min
# [CV] END max_features=1.0, max_samples=100, n_estimators=400; total time= 1.1min
# [CV] END max_features=1.0, max_samples=100, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=100, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=100, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=100, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=100, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=100, n_estimators=600; total time= 1.7min
# [CV] END max_features=1.0, max_samples=100, n_estimators=600; total time= 1.6min
# [CV] END max_features=1.0, max_samples=100, n_estimators=600; total time= 1.5min
# [CV] END max_features=1.0, max_samples=100, n_estimators=600; total time= 1.6min
# [CV] END max_features=1.0, max_samples=100, n_estimators=600; total time= 1.6min
# [CV] END max_features=1.0, max_samples=200, n_estimators=100; total time=  17.0s
# [CV] END max_features=1.0, max_samples=200, n_estimators=100; total time=  17.3s
# [CV] END max_features=1.0, max_samples=200, n_estimators=100; total time=  15.9s
# [CV] END max_features=1.0, max_samples=100, n_estimators=700; total time= 1.9min
# [CV] END max_features=1.0, max_samples=200, n_estimators=100; total time=  17.0s
# [CV] END max_features=1.0, max_samples=100, n_estimators=700; total time= 1.9min
# [CV] END max_features=1.0, max_samples=200, n_estimators=100; total time=  17.4s
# [CV] END max_features=1.0, max_samples=100, n_estimators=700; total time= 1.9min
# [CV] END max_features=1.0, max_samples=100, n_estimators=700; total time= 1.9min
# [CV] END max_features=1.0, max_samples=100, n_estimators=700; total time= 1.9min
# [CV] END max_features=1.0, max_samples=200, n_estimators=200; total time=  34.2s
# [CV] END max_features=1.0, max_samples=200, n_estimators=200; total time=  33.4s
# [CV] END max_features=1.0, max_samples=200, n_estimators=200; total time=  34.4s
# [CV] END max_features=1.0, max_samples=200, n_estimators=200; total time=  33.0s
# [CV] END max_features=1.0, max_samples=100, n_estimators=800; total time= 2.2min
# [CV] END max_features=1.0, max_samples=200, n_estimators=200; total time=  33.5s
# [CV] END max_features=1.0, max_samples=100, n_estimators=800; total time= 2.2min
# [CV] END max_features=1.0, max_samples=200, n_estimators=300; total time=  47.5s
# [CV] END max_features=1.0, max_samples=200, n_estimators=300; total time=  51.4s
# [CV] END max_features=1.0, max_samples=100, n_estimators=800; total time= 2.2min
# [CV] END max_features=1.0, max_samples=100, n_estimators=800; total time= 2.2min
# [CV] END max_features=1.0, max_samples=100, n_estimators=800; total time= 2.1min
# [CV] END max_features=1.0, max_samples=200, n_estimators=300; total time=  52.5s
# [CV] END max_features=1.0, max_samples=200, n_estimators=300; total time=  49.7s
# [CV] END max_features=1.0, max_samples=200, n_estimators=300; total time=  50.9s
# [CV] END max_features=1.0, max_samples=200, n_estimators=400; total time= 1.1min
# [CV] END max_features=1.0, max_samples=200, n_estimators=400; total time= 1.1min
# [CV] END max_features=1.0, max_samples=200, n_estimators=400; total time= 1.1min
# [CV] END max_features=1.0, max_samples=200, n_estimators=400; total time= 1.1min
# [CV] END max_features=1.0, max_samples=200, n_estimators=400; total time= 1.1min
# [CV] END max_features=1.0, max_samples=200, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=200, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=200, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=200, n_estimators=500; total time= 1.5min
# [CV] END max_features=1.0, max_samples=200, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=200, n_estimators=600; total time= 1.7min
# [CV] END max_features=1.0, max_samples=200, n_estimators=600; total time= 1.7min
# [CV] END max_features=1.0, max_samples=200, n_estimators=600; total time= 1.6min
# [CV] END max_features=1.0, max_samples=200, n_estimators=600; total time= 1.7min
# [CV] END max_features=1.0, max_samples=200, n_estimators=600; total time= 1.7min
# [CV] END max_features=1.0, max_samples=300, n_estimators=100; total time=  17.0s
# [CV] END max_features=1.0, max_samples=300, n_estimators=100; total time=  16.6s
# [CV] END max_features=1.0, max_samples=200, n_estimators=700; total time= 2.0min
# [CV] END max_features=1.0, max_samples=300, n_estimators=100; total time=  19.5s
# [CV] END max_features=1.0, max_samples=200, n_estimators=700; total time= 2.0min
# [CV] END max_features=1.0, max_samples=300, n_estimators=100; total time=  17.5s
# [CV] END max_features=1.0, max_samples=300, n_estimators=100; total time=  17.6s
# [CV] END max_features=1.0, max_samples=200, n_estimators=700; total time= 2.0min
# [CV] END max_features=1.0, max_samples=200, n_estimators=700; total time= 2.0min
# [CV] END max_features=1.0, max_samples=300, n_estimators=200; total time=  34.5s
# [CV] END max_features=1.0, max_samples=200, n_estimators=700; total time= 2.0min
# [CV] END max_features=1.0, max_samples=300, n_estimators=200; total time=  33.1s
# [CV] END max_features=1.0, max_samples=300, n_estimators=200; total time=  35.7s
# [CV] END max_features=1.0, max_samples=300, n_estimators=200; total time=  36.3s
# [CV] END max_features=1.0, max_samples=200, n_estimators=800; total time= 2.2min
# [CV] END max_features=1.0, max_samples=200, n_estimators=800; total time= 2.3min
# [CV] END max_features=1.0, max_samples=300, n_estimators=200; total time=  35.8s
# [CV] END max_features=1.0, max_samples=200, n_estimators=800; total time= 2.2min
# [CV] END max_features=1.0, max_samples=200, n_estimators=800; total time= 2.2min
# [CV] END max_features=1.0, max_samples=300, n_estimators=300; total time=  49.5s
# [CV] END max_features=1.0, max_samples=300, n_estimators=300; total time=  54.0s
# [CV] END max_features=1.0, max_samples=300, n_estimators=300; total time=  53.8s
# [CV] END max_features=1.0, max_samples=200, n_estimators=800; total time= 2.2min
# [CV] END max_features=1.0, max_samples=300, n_estimators=300; total time=  54.1s
# [CV] END max_features=1.0, max_samples=300, n_estimators=300; total time=  54.5s
# [CV] END max_features=1.0, max_samples=300, n_estimators=400; total time= 1.2min
# [CV] END max_features=1.0, max_samples=300, n_estimators=400; total time= 1.1min
# [CV] END max_features=1.0, max_samples=300, n_estimators=400; total time= 1.2min
# [CV] END max_features=1.0, max_samples=300, n_estimators=400; total time= 1.2min
# [CV] END max_features=1.0, max_samples=300, n_estimators=400; total time= 1.2min
# [CV] END max_features=1.0, max_samples=300, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=300, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=300, n_estimators=500; total time= 1.5min
# [CV] END max_features=1.0, max_samples=300, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=300, n_estimators=500; total time= 1.5min
# [CV] END max_features=1.0, max_samples=300, n_estimators=600; total time= 1.8min
# [CV] END max_features=1.0, max_samples=300, n_estimators=600; total time= 1.8min
# [CV] END max_features=1.0, max_samples=300, n_estimators=600; total time= 1.7min
# [CV] END max_features=1.0, max_samples=300, n_estimators=600; total time= 1.8min
# [CV] END max_features=1.0, max_samples=300, n_estimators=600; total time= 1.7min
# [CV] END max_features=1.0, max_samples=400, n_estimators=100; total time=  17.8s
# [CV] END max_features=1.0, max_samples=400, n_estimators=100; total time=  18.7s
# [CV] END max_features=1.0, max_samples=300, n_estimators=700; total time= 2.0min
# [CV] END max_features=1.0, max_samples=300, n_estimators=700; total time= 2.0min
# [CV] END max_features=1.0, max_samples=400, n_estimators=100; total time=  18.0s
# [CV] END max_features=1.0, max_samples=400, n_estimators=100; total time=  18.5s
# [CV] END max_features=1.0, max_samples=400, n_estimators=100; total time=  17.7s
# [CV] END max_features=1.0, max_samples=300, n_estimators=700; total time= 2.0min
# [CV] END max_features=1.0, max_samples=300, n_estimators=700; total time= 2.0min
# [CV] END max_features=1.0, max_samples=300, n_estimators=700; total time= 2.0min
# [CV] END max_features=1.0, max_samples=400, n_estimators=200; total time=  35.0s
# [CV] END max_features=1.0, max_samples=400, n_estimators=200; total time=  38.3s
# [CV] END max_features=1.0, max_samples=400, n_estimators=200; total time=  34.7s
# [CV] END max_features=1.0, max_samples=400, n_estimators=200; total time=  33.9s
# [CV] END max_features=1.0, max_samples=300, n_estimators=800; total time= 2.4min
# [CV] END max_features=1.0, max_samples=300, n_estimators=800; total time= 2.4min
# [CV] END max_features=1.0, max_samples=400, n_estimators=200; total time=  37.5s
# [CV] END max_features=1.0, max_samples=300, n_estimators=800; total time= 2.3min
# [CV] END max_features=1.0, max_samples=400, n_estimators=300; total time=  52.7s
# [CV] END max_features=1.0, max_samples=400, n_estimators=300; total time=  49.7s
# [CV] END max_features=1.0, max_samples=300, n_estimators=800; total time= 2.3min
# [CV] END max_features=1.0, max_samples=400, n_estimators=300; total time=  53.1s
# [CV] END max_features=1.0, max_samples=400, n_estimators=300; total time=  53.6s
# [CV] END max_features=1.0, max_samples=400, n_estimators=300; total time=  51.7s
# [CV] END max_features=1.0, max_samples=300, n_estimators=800; total time= 2.3min
# [CV] END max_features=1.0, max_samples=400, n_estimators=400; total time= 1.1min
# [CV] END max_features=1.0, max_samples=400, n_estimators=400; total time= 1.1min
# [CV] END max_features=1.0, max_samples=400, n_estimators=400; total time= 1.2min
# [CV] END max_features=1.0, max_samples=400, n_estimators=400; total time= 1.2min
# [CV] END max_features=1.0, max_samples=400, n_estimators=400; total time= 1.2min
# [CV] END max_features=1.0, max_samples=400, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=400, n_estimators=500; total time= 1.4min
# [CV] END max_features=1.0, max_samples=400, n_estimators=500; total time= 1.5min
# [CV] END max_features=1.0, max_samples=400, n_estimators=500; total time= 1.5min
# [CV] END max_features=1.0, max_samples=400, n_estimators=500; total time= 1.5min
# [CV] END max_features=1.0, max_samples=400, n_estimators=600; total time= 1.8min
# [CV] END max_features=1.0, max_samples=400, n_estimators=600; total time= 1.8min
# [CV] END max_features=1.0, max_samples=400, n_estimators=600; total time= 1.7min
# [CV] END max_features=1.0, max_samples=400, n_estimators=600; total time= 1.8min
# [CV] END max_features=1.0, max_samples=400, n_estimators=600; total time= 1.8min
# [CV] END max_features=1.0, max_samples=400, n_estimators=700; total time= 2.0min
# [CV] END max_features=1.0, max_samples=400, n_estimators=700; total time= 1.9min
# [CV] END max_features=1.0, max_samples=400, n_estimators=700; total time= 1.8min
# [CV] END max_features=1.0, max_samples=400, n_estimators=700; total time= 1.8min
# [CV] END max_features=1.0, max_samples=400, n_estimators=700; total time= 1.7min
# [CV] END max_features=1.0, max_samples=400, n_estimators=800; total time= 1.7min
# [CV] END max_features=1.0, max_samples=400, n_estimators=800; total time= 1.8min
# [CV] END max_features=1.0, max_samples=400, n_estimators=800; total time= 1.5min
# [CV] END max_features=1.0, max_samples=400, n_estimators=800; total time= 1.5min
# [CV] END max_features=1.0, max_samples=400, n_estimators=800; total time= 1.3min
# GridSearchCV(estimator=IsolationForest(n_jobs=-1, random_state=42), n_jobs=-1,
#              param_grid={'max_features': [0.25, 0.5, 0.75, 1.0],
#                          'max_samples': range(100, 500, 100),
#                          'n_estimators': range(100, 900, 100)},
#              scoring=make_scorer(roc_auc_score), verbose=2)

# %%
ISO_grid_scores = score_model(ISO_grid, X_test_transformed, y_test, map={-1:1, 1:0})
ISO_grid_scores
# Out:
# {'accuracy': 0.8752060056100793,
#  'precision': 0.08237224100218732,
#  'recall': 0.9468571428571428,
#  'f1': 0.15155949876520627,
#  'MCC': 0.2589415920796484,
#  'ROC-AUC': 0.9106048209946352,
#  'AUPR': 0.07862032914933231}

# %%
# param_grid = {'n_neighbors':range(10, 100, 5),
#               'p':[1, 2],
#               'contamination':['auto', sum(y_train)/len(y_train)]}

# LOF_grid = GridSearchCV(LocalOutlierFactor(novelty=True, n_jobs=-1),
#                         param_grid,
#                         scoring = scorer_dict,
#                         refit='accuracy',
#                         verbose=2,
#                         n_jobs=-1)
# LOF_grid.fit(X_train_transformed, y_train)

# %%
# LOF_grid_scores = score_model(LOF_grid, X_test_transformed, y_test, map={1:0, -1:1})
# LOF_grid_scores

# %%
grid_scores = {
            'Decision Tree': dec_tree_grid_scores,
            'Random Forest': random_forest_scores_grid,
            'K-NN': KNN_grid_scores,
            'MLP': MLP_grid_scores,
            'SVM': SVM_grid_scores,
            # 'LOF': LOF_grid_scores,
            # 'IF': ISO_grid_scores
            }

# %%
grid_scores_df = pd.DataFrame(grid_scores)

# %%
grid_scores_df.to_csv('grid_search.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/stu15/s10/mjh9122/Research/fraud_detection/notebooks/hyperparams/grid_search.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bberyllium/home/stu15/s10/mjh9122/Research/fraud_detection/notebooks/hyperparams/grid_search.ipynb#Y110sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> grid_scores_df.to_csv('grid_search.csv')
#
# NameError: name 'grid_scores_df' is not defined
