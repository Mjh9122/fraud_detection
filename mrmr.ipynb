# %%
from mrmr import mrmr_classif
import numpy as np
import pandas as pd

# %%
X = pd.read_csv('./active_datasets/original_paper_features_train.csv')
y = pd.read_csv('./active_datasets/y_train.csv', header=None)
X.describe()
# Out:
#               amount  degree_centrality_merchant  degree_centrality_customer
# count  445982.000000               445982.000000               445982.000000  \
# mean        0.004553                    0.669229                    0.803777
# std         0.013458                    0.226376                    0.152787
# min         0.000000                    0.000000                    0.000000
# 25%         0.001648                    0.685776                    0.784173
# 50%         0.003227                    0.685776                    0.841727
# 75%         0.005109                    0.685776                    0.884892
# max         1.000000                    1.000000                    1.000000
#
#        lpa_merchant  lpa_customer  page_rank_merchant  page_rank_customer
# count      445982.0      445982.0       445982.000000       445982.000000  \
# mean            0.0           0.0            0.693785            0.755828
# std             0.0           0.0            0.228088            0.140632
# min             0.0           0.0            0.000000            0.000000
# 25%             0.0           0.0            0.716938            0.737065
# 50%             0.0           0.0            0.716938            0.789180
# 75%             0.0           0.0            0.716938            0.829808
# max             0.0           0.0            1.000000            1.000000
#
#        merchant_fraud_rate  customer_fraud_rate  category_fraud_rate
# count        445982.000000        445982.000000        445982.000000
# mean              0.007229             0.004506             0.008873
# std               0.084716             0.057989             0.093776
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             0.000000
# 75%               0.000000             0.000000             0.000000
# max               1.000000             1.000000             1.000000

# %%
selected_features = mrmr_classif(X=X, y=y, K=len(X.columns), return_scores=True)
# Out:
# 100%|██████████| 8/8 [00:05<00:00,  1.34it/s]

# %%
selected_features
# Out:
# (['merchant_fraud_rate',
#   'customer_fraud_rate',
#   'amount',
#   'category_fraud_rate',
#   'degree_centrality_customer',
#   'degree_centrality_merchant',
#   'page_rank_customer',
#   'page_rank_merchant'],
#  amount                        137985.103832
#  degree_centrality_merchant         0.953303
#  degree_centrality_customer         2.736424
#  page_rank_merchant                 0.896517
#  page_rank_customer                 2.747095
#  merchant_fraud_rate           272918.272053
#  customer_fraud_rate           114429.344928
#  category_fraud_rate           139787.464067
#  dtype: float64,
#                                amount  degree_centrality_merchant
#  amount                      0.001000                    0.001000  \
#  degree_centrality_merchant  0.001162                    0.001000
#  degree_centrality_customer  0.001000                    0.001000
#  page_rank_merchant          0.001170                    0.998493
#  page_rank_customer          0.001000                    0.235075
#  merchant_fraud_rate         0.001000                    0.001000
#  customer_fraud_rate         0.001000                    0.001000
#  category_fraud_rate         0.394264                    0.001000
#
#                              degree_centrality_customer  page_rank_merchant
#  amount                                        0.001000               0.001  \
#  degree_centrality_merchant                    0.259474               0.001
#  degree_centrality_customer                    0.001000               0.001
#  page_rank_merchant                            0.263245               0.001
#  page_rank_customer                            0.992888               0.001
#  merchant_fraud_rate                           0.001000               0.001
#  customer_fraud_rate                           0.001000               0.001
#  category_fraud_rate                           0.001000               0.001
#
#                              page_rank_customer  merchant_fraud_rate
#  amount                                0.001000             0.440904  \
#  degree_centrality_merchant            0.001000             0.003372
#  degree_centrality_customer            0.001000             0.004003
#  page_rank_merchant                    0.238556             0.003316
#  page_rank_customer                    0.001000             0.004269
#  merchant_fraud_rate                   0.001000             0.001000
#  customer_fraud_rate                   0.001000             0.290963
#  category_fraud_rate                   0.001000             0.677506
#
#                              customer_fraud_rate  category_fraud_rate
#  amount                                 0.214056             0.001000
#  degree_centrality_merchant             0.003105             0.003578
#  degree_centrality_customer             0.001953             0.002957
#  page_rank_merchant                     0.003128             0.003616
#  page_rank_customer                     0.001869             0.003173
#  merchant_fraud_rate                    0.001000             0.001000
#  customer_fraud_rate                    0.001000             0.001000
#  category_fraud_rate                    0.226855             0.001000  )
