# %%
from mrmr import mrmr_classif
import numpy as np
import pandas as pd

# %%
X = pd.read_csv('./active_datasets/all_features_train.csv', header=None)
y = pd.read_csv('./active_datasets/y_train.csv', header=None)

# %%
selected_features = mrmr_classif(X=X, y=y, K=len(X.columns), return_scores=True)
# Out:
# 100%|██████████| 19/19 [00:18<00:00,  1.03it/s]

# %%
selected_features
# Out:
# ([16, 17, 0, 18, 7, 10, 2, 4, 15, 14, 6, 1, 5, 12, 13, 3, 8, 9, 11],
#  0     137985.103832
#  1          0.953303
#  2          3.188846
#  3          0.227071
#  4          1.477684
#  5          0.896517
#  6          0.989852
#  7          3.629113
#  8          0.068055
#  9          0.014518
#  10         1.048092
#  11         0.012739
#  12         0.827254
#  13         0.452575
#  14         1.244329
#  15         1.252376
#  16    272918.272053
#  17    114429.344928
#  18    139787.464067
#  dtype: float64,
#            0         1         2         3         4         5         6   \
#  0   0.001000  0.001000  0.001000  0.001000  0.001000  0.001000  0.001000
#  1   0.001162  0.001000  0.275330  0.001000  0.147301  0.001000  0.999200
#  2   0.001000  0.001000  0.001000  0.001000  0.001000  0.001000  0.001000
#  3   0.001000  0.070703  0.012270  0.001000  0.097330  0.017112  0.071248
#  4   0.002301  0.001000  0.448718  0.001000  0.001000  0.001000  0.001000
# ...
