# %%
from mrmr import mrmr_classif
import numpy as np
import pandas as pd

# %%
X = pd.read_csv('./active_datasets/all_features_train.csv')
y = pd.read_csv('./active_datasets/y_train.csv', header=None)
X.describe()
# Out:
#               amount  degree_centrality_merchant  degree_centrality_customer
# count  445982.000000               445982.000000               445982.000000  \
# mean        0.004553                    0.746005                    0.591979
# std         0.013458                    0.332019                    0.111790
# min         0.000000                    0.000000                    0.000000
# 25%         0.001648                    0.685885                    0.565657
# 50%         0.003227                    1.000000                    0.626263
# 75%         0.005109                    1.000000                    0.661616
# max         1.000000                    1.000000                    1.000000
#
#         lpa_merchant   lpa_customer  page_rank_merchant  page_rank_customer
# count  445982.000000  445982.000000       445982.000000       445982.000000  \
# mean        0.255548       0.190717            0.756944            0.482312
# std         0.319455       0.289308            0.330070            0.084577
# min         0.000000       0.000000            0.000000            0.000000
# 25%         0.000000       0.000000            0.717123            0.463901
# 50%         0.000000       0.000000            1.000000            0.506266
# 75%         0.666667       0.333333            1.000000            0.531583
# max         1.000000       1.000000            1.000000            1.000000
#
#        page_rank_w_merchant  page_rank_w_customer
# count         445982.000000         445982.000000  \
# mean               0.754817              0.087945
# std                0.322352              0.049309
# min                0.000000              0.000000
# 25%                0.699216              0.074389
# 50%                1.000000              0.082602
# 75%                1.000000              0.091476
# max                1.000000              1.000000
#
#        closeness_centrality_merchant  ...  load_centrality_w_customer
# count                  445982.000000  ...               445982.000000  \
# mean                        0.798130  ...                    0.005896
# std                         0.226157  ...                    0.056555
# min                         0.000000  ...                    0.000000
# 25%                         0.789021  ...                    0.000000
# 50%                         0.789021  ...                    0.000000
# 75%                         1.000000  ...                    0.000000
# max                         1.000000  ...                    1.000000
#
#        second_order_centrality_merchant  second_order_centrality_customer
# count                     445982.000000                     445982.000000  \
# mean                           0.003729                          0.164576
# std                            0.011655                          0.057186
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.134646
# 50%                            0.001702                          0.152969
# 75%                            0.001702                          0.199030
# max                            1.000000                          1.000000
#
#        laplacian_centrality_merchant  laplacian_centrality_customer
# count                  445982.000000                  445982.000000  \
# mean                        0.666839                       0.681762
# std                         0.368387                       0.170947
# min                         0.000000                       0.000000
# 25%                         0.470651                       0.606167
# 50%                         1.000000                       0.724915
# 75%                         1.000000                       0.800363
# max                         1.000000                       1.000000
#
#        laplacian_centrality_w_merchant  laplacian_centrality_w_customer
# count                    445982.000000                    445982.000000  \
# mean                          0.667160                         0.310738
# std                           0.367506                         0.079080
# min                           0.000000                         0.000000
# 25%                           0.469946                         0.271806
# 50%                           1.000000                         0.322069
# 75%                           1.000000                         0.360870
# max                           1.000000                         1.000000
#
#        merchant_fraud_rate  customer_fraud_rate  category_fraud_rate
# count        445982.000000        445982.000000        445982.000000
# mean              0.007229             0.004506             0.008873
# std               0.084716             0.057989             0.093776
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             0.000000
# 75%               0.000000             0.000000             0.000000
# max               1.000000             1.000000             1.000000
#
# [8 rows x 24 columns]

# %%
mrmr_out = mrmr_classif(X=X, y=y, K=len(X.columns), return_scores=True)
# Out:
# 100%|██████████| 24/24 [00:13<00:00,  1.80it/s]

# %%
a, b, c = selected_features

# %%
b.sort_values().plot.bar()
# Out:
# <AxesSubplot: >
